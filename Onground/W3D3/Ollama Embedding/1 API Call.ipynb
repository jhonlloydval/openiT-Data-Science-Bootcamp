# %%
import ollama

response = ollama.embed(
    model='nomic-embed-text',
    input='Show me the embedding for this sentence.',
)

print(response.embeddings)
print(f'Dimensions: {len(response.embeddings[0])}')
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[3], line 3
#       1 import ollama
#       2
# ----> 3 response = ollama.embed(
#       4     model='nomic-embed-text',
#       5     input='Show me the embedding for this sentence.',
#       6 )
#
# File ~/DataScience_BOOTCAMP/.venv/lib/python3.12/site-packages/ollama/_client.py:415, in Client.embed(self, model, input, truncate, options, keep_alive, dimensions)
#     406 def embed(
#     407   self,
#     408   model: str = '',
#    (...)    413   dimensions: Optional[int] = None,
#     414 ) -> EmbedResponse:
# --> 415   return self._request(
#     416     EmbedResponse,
#     417     'POST',
#     418     '/api/embed',
#     419     json=EmbedRequest(
#     420       model=model,
#     421       input=input,
#     422       truncate=truncate,
#     423       options=options,
#     424       keep_alive=keep_alive,
#     425       dimensions=dimensions,
#     426     ).model_dump(exclude_none=True),
#     427   )
#
# File ~/DataScience_BOOTCAMP/.venv/lib/python3.12/site-packages/ollama/_client.py:199, in Client._request(self, cls, stream, *args, **kwargs)
#     195         yield cls(**part)
#     197   return inner()
# --> 199 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/DataScience_BOOTCAMP/.venv/lib/python3.12/site-packages/ollama/_client.py:143, in Client._request_raw(self, *args, **kwargs)
#     141   return r
#     142 except httpx.HTTPStatusError as e:
# --> 143   raise ResponseError(e.response.text, e.response.status_code) from None
#     144 except httpx.ConnectError:
#     145   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: model "nomic-embed-text" not found, try pulling it first (status code: 404)
